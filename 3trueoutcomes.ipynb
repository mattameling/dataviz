# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
import pybaseball as py
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
from pybaseball import team_pitching 
pitching_data = team_pitching(2000,2022)

# %%
print(pitching_data.head())
# Out:
#    teamIDfg  Season Team  Age    W   L   ERA    G   GS  CG  ...    LA  \
# 0        22    2022  LAD   30   20   8  2.14  121   28   1  ...  14.2
# 1         9    2022  NYY   29   21   8  2.59  133   29   0  ...  11.7
# 2        21    2022  HOU   29   19  11  2.85  127   30   0  ...  14.2
# 3        28    2015  STL   28  100  62  2.94  677  162   1  ...   9.9
# 4        26    2011  PHI   29  102  60  3.02  556  162  18  ...   NaN
#
#    Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xERA
# 0     40.0    0.061  113.9    201.0     0.306     656  0.163  0.288   NaN
# 1     40.0    0.058  116.2    257.0     0.374     687  0.168  0.298   NaN
# 2     55.0    0.075  119.1    279.0     0.381     733  0.142  0.257   NaN
# 3    183.0    0.043  119.2   1355.0     0.316    4283  0.167  0.265   NaN
# 4      0.0      NaN    NaN      0.0       NaN       0  0.182  0.277   NaN
#
# [5 rows x 333 columns]

# %%
pitching_data.columns
# Out:
# Index(['teamIDfg', 'Season', 'Team', 'Age', 'W', 'L', 'ERA', 'G', 'GS', 'CG',
#        ...
#        'LA', 'Barrels', 'Barrel%', 'maxEV', 'HardHit', 'HardHit%', 'Events',
#        'CStr%', 'CSW%', 'xERA'],
#       dtype='object', length=333)

# %%
idf = pitching_data.interactive()

# %%
year_slider = pn.widgets.IntSlider(name='Year Slider', start=2000, end=2022, step=1)
year_slider
# Out:
# IntSlider(end=2022, name='Year Slider', start=2000, value=2000)

# %%
league_average = pitching_data.groupby('Season', as_index=False)['K/9'].mean()
plt.scatter(pitching_data['Season'], pitching_data['K/9'])
plt.plot(league_average['Season'], league_average['K/9'], c='red')
plt.ylabel('K/9')
plt.xlabel('Year')
plt.title('Strikeouts per Game over Time')
# Out:
# Text(0.5, 1.0, 'Strikeouts per Game over Time')

# %%
from pybaseball import team_batting 
batting_data = team_batting(2000,2022)

# %%
print(batting_data.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 print(batting_data.column())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
batting_data.columns
# Out:
# Index(['teamIDfg', 'Season', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B',
#        ...
#        'Barrel%', 'maxEV', 'HardHit', 'HardHit%', 'Events', 'CStr%', 'CSW%',
#        'xBA', 'xSLG', 'xwOBA'],
#       dtype='object', length=318)

# %%
league_averageb = batting_data.groupby('Season', as_index=False)['Barrel%'].mean()
plt.plot(league_averageb['Season'], league_average['K/9'], c='red')
